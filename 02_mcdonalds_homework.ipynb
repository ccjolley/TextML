# %% [markdown]
# # Homework with McDonald's sentiment data

# %% [markdown]
# ## Imaginary problem statement
#
# McDonald's receives **thousands of customer comments** on their website per day, and many of them are negative. Their corporate employees don't have time to read every single comment, but they do want to read a subset of comments that they are most interested in. In particular, the media has recently portrayed their employees as being rude, and so they want to review any comments about **rude service** so that they can update their employee training accordingly.
#
# McDonald's has hired you to develop a system that ranks each comment by the **likelihood that it is referring to rude service**. They will use your system to build a "rudeness dashboard" for their corporate employees, so that employees can spend a few minutes each day examining the **most relevant recent comments**.
#
# ## Description of the data
#
# Before hiring you, McDonald's used the [CrowdFlower platform](http://www.crowdflower.com/data-for-everyone) to pay humans to **hand-annotate** about 1500 comments with the **type of complaint**. The complaint types are listed below, with the encoding used in the data listed in parentheses:
#
# - Bad Food (BadFood)
# - Bad Neighborhood (ScaryMcDs)
# - Cost (Cost)
# - Dirty Location (Filthy)
# - Missing Item (MissingFood)
# - Problem with Order (OrderProblem)
# - Rude Service (RudeService)
# - Slow Service (SlowService)
# - None of the above (na)

# %% [markdown]
# ## Task 1
#
# Read **`mcdonalds.csv`** into a pandas DataFrame and examine it. (It can be found in the **`data`** directory of the course repository.)
#
# - The **policies_violated** column lists the type of complaint. If there is more than one type, the types are separated by newline characters.
# - The **policies_violated:confidence** column lists CrowdFlower's confidence in the judgments of its human annotators for that row (higher is better).
# - The **city** column is the McDonald's location.
# - The **review** column is the actual text comment.

# %%
import pandas as pd
mcd_raw = pd.read_csv('mcdonalds.csv')
mcd_raw
# Out:
#        _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     679455653   False   finalized                   3      2/21/15 0:36
# 1     679455654   False   finalized                   3      2/21/15 0:27
# 2     679455655   False   finalized                   3      2/21/15 0:26
# 3     679455656   False   finalized                   3      2/21/15 0:27
# 4     679455657   False   finalized                   3      2/21/15 0:27
# 5     679455658   False   finalized                   3      2/21/15 0:13
# 6     679455659   False   finalized                   3      2/21/15 0:36
# 7     679455660   False   finalized                   3      2/21/15 0:15
# 8     679455661   False   finalized                   3      2/21/15 0:29
# 9     679455662   False   finalized                   3      2/21/15 0:12
# 10    679455663   False   finalized                   3      2/21/15 0:38
# 11    679455664   False   finalized                   3      2/21/15 0:40
# 12    679455665   False   finalized                   3      2/21/15 0:24
# 13    679455666   False   finalized                   3      2/21/15 0:15
# 14    679455667   False   finalized                   3      2/21/15 0:37
# 15    679455668   False   finalized                   3      2/21/15 0:38
# 16    679455669   False   finalized                   3      2/21/15 2:30
# 17    679455670   False   finalized                   3      2/21/15 0:15
# 18    679455671   False   finalized                   3      2/21/15 0:44
# 19    679455672   False   finalized                   3      2/21/15 0:45
# 20    679455673   False   finalized                   3      2/21/15 1:07
# 21    679455674   False   finalized                   3      2/21/15 0:43
# 22    679455675   False   finalized                   3      2/21/15 0:36
# 23    679455676   False   finalized                   3      2/21/15 0:28
# 24    679455677   False   finalized                   3      2/21/15 0:16
# 25    679455678   False   finalized                   3      2/21/15 0:13
# 26    679455679   False   finalized                   3      2/21/15 0:54
# 27    679455680   False   finalized                   3      2/21/15 0:15
# 28    679455681   False   finalized                   3      2/21/15 0:13
# 29    679455682   False   finalized                   3      2/21/15 0:37
# ...         ...     ...         ...                 ...               ...
# 1495  679457178   False   finalized                   3      2/21/15 0:37
# 1496  679457179   False   finalized                   3      2/21/15 0:15
# 1497  679457180   False   finalized                   3      2/21/15 0:21
# 1498  679457181   False   finalized                   3      2/21/15 0:38
# 1499  679472025   False   finalized                   3      2/21/15 0:21
# 1500  679472293   False   finalized                   3      2/21/15 0:44
# 1501  679473526   False   finalized                   3      2/21/15 0:17
# 1502  679477946   False   finalized                   3      2/21/15 0:30
# 1503  679480418   False   finalized                   3      2/21/15 0:54
# 1504  679480834   False   finalized                   3      2/21/15 0:28
# 1505  679482559   False   finalized                   3      2/21/15 0:33
# 1506  679483385   False   finalized                   3      2/21/15 0:21
# 1507  679483735   False   finalized                   3      2/21/15 0:20
# 1508  679484306   False   finalized                   3      2/21/15 0:28
# 1509  679484693   False   finalized                   3      2/21/15 0:20
# 1510  679485181   False   finalized                   3      2/21/15 0:36
# 1511  679492436   False   finalized                   3      2/21/15 0:24
# 1512  679494190   False   finalized                   3      2/21/15 0:09
# 1513  679494608   False   finalized                   3      2/21/15 0:34
# 1514  679495317   False   finalized                   3      2/21/15 0:09
# 1515  679495463   False   finalized                   3      2/21/15 0:45
# 1516  679495976   False   finalized                   3      2/21/15 1:01
# 1517  679497650   False   finalized                   3      2/21/15 0:22
# 1518  679499048   False   finalized                   3      2/21/15 0:34
# 1519  679499432   False   finalized                   3      2/21/15 0:38
# 1520  679500008   False   finalized                   3      2/21/15 0:13
# 1521  679500224   False   finalized                   3      2/21/15 0:27
# 1522  679500608   False   finalized                   3      2/21/15 0:24
# 1523  679501257   False   finalized                   3      2/21/15 0:32
# 1524  679501402   False   finalized                   3      2/21/15 0:27
#
#                           policies_violated policies_violated:confidence  \
# 0         RudeService\nOrderProblem\nFilthy          1.0\n0.6667\n0.6667
# 1                               RudeService                            1
# 2                 SlowService\nOrderProblem                     1.0\n1.0
# 3                                        na                       0.6667
# 4                               RudeService                            1
# 5                      BadFood\nSlowService               0.7111\n0.6444
# 6                    SlowService\nScaryMcDs               0.6562\n0.6562
# 7                               RudeService                       0.6801
# 8     SlowService\nRudeService\nMissingFood             1.0\n1.0\n0.6667
# 9                                        na                            1
# 10                              SlowService                            1
# 11                              RudeService                            1
# 12                              RudeService                       0.6667
# 13                              SlowService                            1
# 14        BadFood\nRudeService\nSlowService          1.0\n0.6928\n0.6655
# 15                   SlowService\nScaryMcDs               0.7112\n0.6641
# 16        SlowService\nMissingFood\nBadFood                1.0\n1.0\n1.0
# 17                              SlowService                            1
# 18                              SlowService                       0.7003
# 19                              RudeService                            1
# 20                                  BadFood                       0.6923
# 21                                ScaryMcDs                       0.6458
# 22                RudeService\nOrderProblem                  1.0\n0.7179
# 23                                  BadFood                            1
# 24                             OrderProblem                       0.6667
# 25                                  BadFood                            1
# 26                     RudeService\nBadFood                  1.0\n0.6216
# 27                          Filthy\nBadFood                  1.0\n0.7037
# 28                 SlowService\nRudeService                     1.0\n1.0
# 29                              SlowService                       0.6416
# ...                                     ...                          ...
# 1495                                     na                            1
# 1496                                     na                       0.6523
# 1497                            SlowService                         0.65
# 1498                                BadFood                            1
# 1499              OrderProblem\nRudeService                  1.0\n0.6966
# 1500                            SlowService                            1
# 1501                          na\nScaryMcDs                0.676\n0.6529
# 1502                            RudeService                            1
# 1503                              ScaryMcDs                       0.7125
# 1504               RudeService\nSlowService                  1.0\n0.7037
# 1505                 RudeService\nScaryMcDs                  1.0\n0.6564
# 1506                                     na                            1
# 1507                              ScaryMcDs                            1
# 1508                                     na                            1
# 1509                   BadFood\nRudeService                  1.0\n0.6909
# 1510                                BadFood                            1
# 1511              RudeService\nOrderProblem                  1.0\n0.6585
# 1512              OrderProblem\nRudeService               0.7056\n0.6377
# 1513                           OrderProblem                            1
# 1514                            SlowService                       0.6246
# 1515                                     na                            1
# 1516                           OrderProblem                            1
# 1517              OrderProblem\nRudeService                  1.0\n0.6786
# 1518                           OrderProblem                            1
# 1519                            RudeService                            1
# 1520                           OrderProblem                       0.6754
# 1521           SlowService\nFilthy\nBadFood                1.0\n1.0\n1.0
# 1522                              ScaryMcDs                       0.6458
# 1523                              ScaryMcDs                       0.6407
# 1524                 ScaryMcDs\nSlowService                  1.0\n0.6667
#
#              city  policies_violated_gold  \
# 0         Atlanta                     NaN
# 1         Atlanta                     NaN
# 2         Atlanta                     NaN
# 3         Atlanta                     NaN
# 4         Atlanta                     NaN
# 5         Atlanta                     NaN
# 6         Atlanta                     NaN
# 7         Atlanta                     NaN
# 8         Atlanta                     NaN
# 9         Atlanta                     NaN
# 10        Atlanta                     NaN
# 11        Atlanta                     NaN
# 12        Atlanta                     NaN
# 13        Atlanta                     NaN
# 14        Atlanta                     NaN
# 15        Atlanta                     NaN
# 16        Atlanta                     NaN
# 17        Atlanta                     NaN
# 18        Atlanta                     NaN
# 19        Atlanta                     NaN
# 20        Atlanta                     NaN
# 21        Atlanta                     NaN
# 22        Atlanta                     NaN
# 23        Atlanta                     NaN
# 24        Atlanta                     NaN
# 25        Atlanta                     NaN
# 26        Atlanta                     NaN
# 27        Atlanta                     NaN
# 28        Atlanta                     NaN
# 29        Atlanta                     NaN
# ...           ...                     ...
# 1495          NaN                     NaN
# 1496          NaN                     NaN
# 1497          NaN                     NaN
# 1498          NaN                     NaN
# 1499      Chicago                     NaN
# 1500    Las Vegas                     NaN
# 1501      Chicago                     NaN
# 1502      Chicago                     NaN
# 1503     New York                     NaN
# 1504  Los Angeles                     NaN
# 1505      Chicago                     NaN
# 1506    Las Vegas                     NaN
# 1507      Chicago                     NaN
# 1508       Dallas                     NaN
# 1509     New York                     NaN
# 1510    Las Vegas                     NaN
# 1511    Las Vegas                     NaN
# 1512      Chicago                     NaN
# 1513      Chicago                     NaN
# 1514      Houston                     NaN
# 1515    Las Vegas                     NaN
# 1516     New York                     NaN
# 1517      Houston                     NaN
# 1518    Las Vegas                     NaN
# 1519          NaN                     NaN
# 1520     Portland                     NaN
# 1521      Houston                     NaN
# 1522     New York                     NaN
# 1523      Chicago                     NaN
# 1524  Los Angeles                     NaN
#
#                                                  review  Unnamed: 10
# 0     I'm not a huge mcds lover, but I've been to be...          NaN
# 1     Terrible customer service. ξI came in at 9:30...          NaN
# 2     First they "lost" my order, actually they gave...          NaN
# 3     I see I'm not the only one giving 1 star. Only...          NaN
# 4     Well, it's McDonald's, so you know what the fo...          NaN
# 5     This has to be one of the worst and slowest Mc...          NaN
# 6     I'm not crazy about this McDonald's. ξThis is...          NaN
# 7     One Star and I'm beng kind. I blame management...          NaN
# 8     Never been upset about any fast food drive thr...          NaN
# 9     This McDonald's has gotten much better. Usuall...          NaN
# 10    Let's start here only reason I came into McDon...          NaN
# 11    Other businesses throughout Metro Atlanta open...          NaN
# 12    The drive thru makes them lost a star since my...          NaN
# 13    Believe it or not, this used to be q really go...          NaN
# 14    As the previous yelpers have already stated, t...          NaN
# 15    25 minutes in drive through line. Gunshots fro...          NaN
# 16    Super slow service, food's terrible like its b...          NaN
# 17    SLOW-SLOW-SLOW! ξDon't go here if you have a ...          NaN
# 18    On your way to the airport or just cruising do...          NaN
# 19    This is the worst McDonalds I have ever seen. ...          NaN
# 20    I had the McCafe Mocha and must say that it wa...          NaN
# 21    GHETTO!! went in yesterday just to get a soda ...          NaN
# 22    I visited mcdonalds on Dec 20, 2011 at 12:54 I...          NaN
# 23    I usually hit the drive thru once or twice a w...          NaN
# 24    What a joke.Don't do take out as you will not ...          NaN
# 25    I wish I can give zero stars. Freezing cold re...          NaN
# 26    I agree with most reviewers on this one. Staff...          NaN
# 27    I don't think this location deserves even one ...          NaN
# 28    This is one rude Mcdonalds! The food takes lon...          NaN
# 29    the managers at this mcdonalds are awesome but...          NaN
# ...                                                 ...          ...
# 1495                 very good mcdonald's ,good service          NaN
# 1496  Came here for the McCafe.Coffee was a little l...          NaN
# 1497  I actually got in an accident trying to leave ...          NaN
# 1498  Came here for breakfast and there was total ch...          NaN
# 1499  I dont like mcdonalds but go once in a great w...          NaN
# 1500  If they went any slower, I would have grown a ...          NaN
# 1501  I am very amazed at the hard working employees...          NaN
# 1502  Managers are rude to customers, I asked if the...          NaN
# 1503  Best place on Park Avenue to meet homeless peo...          NaN
# 1504  Worst customer service ever!!!!!!!!!!!!over 30...          NaN
# 1505  I won't be critical because it was only a Mcdo...          NaN
# 1506  My mom needed to meet a client to pick up docu...          NaN
# 1507  This is not a family-friendly location. There'...          NaN
# 1508  I love this McDonalds! The workers are always ...          NaN
# 1509  Really rude workers and customer service was j...          NaN
# 1510  WORST MCDONALDS EVER!Every single time we have...          NaN
# 1511  Worst service ever!!!! There was so much trash...          NaN
# 1512  Normally I don't review a chain unless somethi...          NaN
# 1513  Every time I come here they mess up my order.....          NaN
# 1514  Don't go here if you're looking for fast food....          NaN
# 1515  Ok ok ok, I know it's only a McDonald's, BUT t...          NaN
# 1516  Okay so I came in here yesterday around 4:15 P...          NaN
# 1517  The drive thru got our order wrong AGAIN. I ca...          NaN
# 1518  Breakfast for the family and kids. ξ8 of us. ...          NaN
# 1519  If I could put zero stars, it would deserve th...          NaN
# 1520  I enjoyed the part where I repeatedly asked if...          NaN
# 1521  Worst McDonalds I've been in in a long time! D...          NaN
# 1522  When I am really craving for McDonald's, this ...          NaN
# 1523  Two points right out of the gate: 1. Thuggery ...          NaN
# 1524  I wanted to grab breakfast one morning before ...          NaN
#
# [1525 rows x 11 columns]

# %% [markdown]
# ## Task 2
#
# Remove any rows from the DataFrame in which the **policies_violated** column has a **null value**. Check the shape of the DataFrame before and after to confirm that you only removed about 50 rows.
#
# - **Note:** Null values are also known as "missing values", and are encoded in pandas with the special value "NaN". This is distinct from the "na" encoding used by CrowdFlower to denote "None of the above". Rows that contain "na" should **not** be removed.
# - **Hint:** This [code snippet](http://chrisalbon.com/python/pandas_missing_data.html) shows different ways for handling missing data in pandas, and includes one strategy that will work for this task.

# %%
import numpy as np
print(mcd_raw.shape)
mcd = mcd_raw.dropna(subset=['policies_violated']).copy()
print(mcd.shape)
# Out:
# (1525, 11)
# (1471, 11)

# %% [markdown]
# ## Task 3
#
# Add a new column to the DataFrame called **"rude"** that is 1 if the **policies_violated** column contains the text "RudeService", and 0 if the **policies_violated** column does not contain "RudeService". The "rude" column is going to be your response variable, so check how many zeros and ones it contains.
#
# - **Hint:** This [code snippet](http://chrisalbon.com/python/pandas_string_munging.html) shows how to use a pandas string method to search for the presence of a sub-string. You will also have to figure out how to convert the boolean results (True/False) to integers (1/0).

# %%
mcd['rude'] = mcd.policies_violated.str.contains('RudeService').astype(int)
mcd
# Out:
#        _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0     679455653   False   finalized                   3      2/21/15 0:36
# 1     679455654   False   finalized                   3      2/21/15 0:27
# 2     679455655   False   finalized                   3      2/21/15 0:26
# 3     679455656   False   finalized                   3      2/21/15 0:27
# 4     679455657   False   finalized                   3      2/21/15 0:27
# 5     679455658   False   finalized                   3      2/21/15 0:13
# 6     679455659   False   finalized                   3      2/21/15 0:36
# 7     679455660   False   finalized                   3      2/21/15 0:15
# 8     679455661   False   finalized                   3      2/21/15 0:29
# 9     679455662   False   finalized                   3      2/21/15 0:12
# 10    679455663   False   finalized                   3      2/21/15 0:38
# 11    679455664   False   finalized                   3      2/21/15 0:40
# 12    679455665   False   finalized                   3      2/21/15 0:24
# 13    679455666   False   finalized                   3      2/21/15 0:15
# 14    679455667   False   finalized                   3      2/21/15 0:37
# 15    679455668   False   finalized                   3      2/21/15 0:38
# 16    679455669   False   finalized                   3      2/21/15 2:30
# 17    679455670   False   finalized                   3      2/21/15 0:15
# 18    679455671   False   finalized                   3      2/21/15 0:44
# 19    679455672   False   finalized                   3      2/21/15 0:45
# 20    679455673   False   finalized                   3      2/21/15 1:07
# 21    679455674   False   finalized                   3      2/21/15 0:43
# 22    679455675   False   finalized                   3      2/21/15 0:36
# 23    679455676   False   finalized                   3      2/21/15 0:28
# 24    679455677   False   finalized                   3      2/21/15 0:16
# 25    679455678   False   finalized                   3      2/21/15 0:13
# 26    679455679   False   finalized                   3      2/21/15 0:54
# 27    679455680   False   finalized                   3      2/21/15 0:15
# 28    679455681   False   finalized                   3      2/21/15 0:13
# 29    679455682   False   finalized                   3      2/21/15 0:37
# ...         ...     ...         ...                 ...               ...
# 1495  679457178   False   finalized                   3      2/21/15 0:37
# 1496  679457179   False   finalized                   3      2/21/15 0:15
# 1497  679457180   False   finalized                   3      2/21/15 0:21
# 1498  679457181   False   finalized                   3      2/21/15 0:38
# 1499  679472025   False   finalized                   3      2/21/15 0:21
# 1500  679472293   False   finalized                   3      2/21/15 0:44
# 1501  679473526   False   finalized                   3      2/21/15 0:17
# 1502  679477946   False   finalized                   3      2/21/15 0:30
# 1503  679480418   False   finalized                   3      2/21/15 0:54
# 1504  679480834   False   finalized                   3      2/21/15 0:28
# 1505  679482559   False   finalized                   3      2/21/15 0:33
# 1506  679483385   False   finalized                   3      2/21/15 0:21
# 1507  679483735   False   finalized                   3      2/21/15 0:20
# 1508  679484306   False   finalized                   3      2/21/15 0:28
# 1509  679484693   False   finalized                   3      2/21/15 0:20
# 1510  679485181   False   finalized                   3      2/21/15 0:36
# 1511  679492436   False   finalized                   3      2/21/15 0:24
# 1512  679494190   False   finalized                   3      2/21/15 0:09
# 1513  679494608   False   finalized                   3      2/21/15 0:34
# 1514  679495317   False   finalized                   3      2/21/15 0:09
# 1515  679495463   False   finalized                   3      2/21/15 0:45
# 1516  679495976   False   finalized                   3      2/21/15 1:01
# 1517  679497650   False   finalized                   3      2/21/15 0:22
# 1518  679499048   False   finalized                   3      2/21/15 0:34
# 1519  679499432   False   finalized                   3      2/21/15 0:38
# 1520  679500008   False   finalized                   3      2/21/15 0:13
# 1521  679500224   False   finalized                   3      2/21/15 0:27
# 1522  679500608   False   finalized                   3      2/21/15 0:24
# 1523  679501257   False   finalized                   3      2/21/15 0:32
# 1524  679501402   False   finalized                   3      2/21/15 0:27
#
#                           policies_violated policies_violated:confidence  \
# 0         RudeService\nOrderProblem\nFilthy          1.0\n0.6667\n0.6667
# 1                               RudeService                            1
# 2                 SlowService\nOrderProblem                     1.0\n1.0
# 3                                        na                       0.6667
# 4                               RudeService                            1
# 5                      BadFood\nSlowService               0.7111\n0.6444
# 6                    SlowService\nScaryMcDs               0.6562\n0.6562
# 7                               RudeService                       0.6801
# 8     SlowService\nRudeService\nMissingFood             1.0\n1.0\n0.6667
# 9                                        na                            1
# 10                              SlowService                            1
# 11                              RudeService                            1
# 12                              RudeService                       0.6667
# 13                              SlowService                            1
# 14        BadFood\nRudeService\nSlowService          1.0\n0.6928\n0.6655
# 15                   SlowService\nScaryMcDs               0.7112\n0.6641
# 16        SlowService\nMissingFood\nBadFood                1.0\n1.0\n1.0
# 17                              SlowService                            1
# 18                              SlowService                       0.7003
# 19                              RudeService                            1
# 20                                  BadFood                       0.6923
# 21                                ScaryMcDs                       0.6458
# 22                RudeService\nOrderProblem                  1.0\n0.7179
# 23                                  BadFood                            1
# 24                             OrderProblem                       0.6667
# 25                                  BadFood                            1
# 26                     RudeService\nBadFood                  1.0\n0.6216
# 27                          Filthy\nBadFood                  1.0\n0.7037
# 28                 SlowService\nRudeService                     1.0\n1.0
# 29                              SlowService                       0.6416
# ...                                     ...                          ...
# 1495                                     na                            1
# 1496                                     na                       0.6523
# 1497                            SlowService                         0.65
# 1498                                BadFood                            1
# 1499              OrderProblem\nRudeService                  1.0\n0.6966
# 1500                            SlowService                            1
# 1501                          na\nScaryMcDs                0.676\n0.6529
# 1502                            RudeService                            1
# 1503                              ScaryMcDs                       0.7125
# 1504               RudeService\nSlowService                  1.0\n0.7037
# 1505                 RudeService\nScaryMcDs                  1.0\n0.6564
# 1506                                     na                            1
# 1507                              ScaryMcDs                            1
# 1508                                     na                            1
# 1509                   BadFood\nRudeService                  1.0\n0.6909
# 1510                                BadFood                            1
# 1511              RudeService\nOrderProblem                  1.0\n0.6585
# 1512              OrderProblem\nRudeService               0.7056\n0.6377
# 1513                           OrderProblem                            1
# 1514                            SlowService                       0.6246
# 1515                                     na                            1
# 1516                           OrderProblem                            1
# 1517              OrderProblem\nRudeService                  1.0\n0.6786
# 1518                           OrderProblem                            1
# 1519                            RudeService                            1
# 1520                           OrderProblem                       0.6754
# 1521           SlowService\nFilthy\nBadFood                1.0\n1.0\n1.0
# 1522                              ScaryMcDs                       0.6458
# 1523                              ScaryMcDs                       0.6407
# 1524                 ScaryMcDs\nSlowService                  1.0\n0.6667
#
#              city  policies_violated_gold  \
# 0         Atlanta                     NaN
# 1         Atlanta                     NaN
# 2         Atlanta                     NaN
# 3         Atlanta                     NaN
# 4         Atlanta                     NaN
# 5         Atlanta                     NaN
# 6         Atlanta                     NaN
# 7         Atlanta                     NaN
# 8         Atlanta                     NaN
# 9         Atlanta                     NaN
# 10        Atlanta                     NaN
# 11        Atlanta                     NaN
# 12        Atlanta                     NaN
# 13        Atlanta                     NaN
# 14        Atlanta                     NaN
# 15        Atlanta                     NaN
# 16        Atlanta                     NaN
# 17        Atlanta                     NaN
# 18        Atlanta                     NaN
# 19        Atlanta                     NaN
# 20        Atlanta                     NaN
# 21        Atlanta                     NaN
# 22        Atlanta                     NaN
# 23        Atlanta                     NaN
# 24        Atlanta                     NaN
# 25        Atlanta                     NaN
# 26        Atlanta                     NaN
# 27        Atlanta                     NaN
# 28        Atlanta                     NaN
# 29        Atlanta                     NaN
# ...           ...                     ...
# 1495          NaN                     NaN
# 1496          NaN                     NaN
# 1497          NaN                     NaN
# 1498          NaN                     NaN
# 1499      Chicago                     NaN
# 1500    Las Vegas                     NaN
# 1501      Chicago                     NaN
# 1502      Chicago                     NaN
# 1503     New York                     NaN
# 1504  Los Angeles                     NaN
# 1505      Chicago                     NaN
# 1506    Las Vegas                     NaN
# 1507      Chicago                     NaN
# 1508       Dallas                     NaN
# 1509     New York                     NaN
# 1510    Las Vegas                     NaN
# 1511    Las Vegas                     NaN
# 1512      Chicago                     NaN
# 1513      Chicago                     NaN
# 1514      Houston                     NaN
# 1515    Las Vegas                     NaN
# 1516     New York                     NaN
# 1517      Houston                     NaN
# 1518    Las Vegas                     NaN
# 1519          NaN                     NaN
# 1520     Portland                     NaN
# 1521      Houston                     NaN
# 1522     New York                     NaN
# 1523      Chicago                     NaN
# 1524  Los Angeles                     NaN
#
#                                                  review  Unnamed: 10  rude
# 0     I'm not a huge mcds lover, but I've been to be...          NaN     1
# 1     Terrible customer service. ξI came in at 9:30...          NaN     1
# 2     First they "lost" my order, actually they gave...          NaN     0
# 3     I see I'm not the only one giving 1 star. Only...          NaN     0
# 4     Well, it's McDonald's, so you know what the fo...          NaN     1
# 5     This has to be one of the worst and slowest Mc...          NaN     0
# 6     I'm not crazy about this McDonald's. ξThis is...          NaN     0
# 7     One Star and I'm beng kind. I blame management...          NaN     1
# 8     Never been upset about any fast food drive thr...          NaN     1
# 9     This McDonald's has gotten much better. Usuall...          NaN     0
# 10    Let's start here only reason I came into McDon...          NaN     0
# 11    Other businesses throughout Metro Atlanta open...          NaN     1
# 12    The drive thru makes them lost a star since my...          NaN     1
# 13    Believe it or not, this used to be q really go...          NaN     0
# 14    As the previous yelpers have already stated, t...          NaN     1
# 15    25 minutes in drive through line. Gunshots fro...          NaN     0
# 16    Super slow service, food's terrible like its b...          NaN     0
# 17    SLOW-SLOW-SLOW! ξDon't go here if you have a ...          NaN     0
# 18    On your way to the airport or just cruising do...          NaN     0
# 19    This is the worst McDonalds I have ever seen. ...          NaN     1
# 20    I had the McCafe Mocha and must say that it wa...          NaN     0
# 21    GHETTO!! went in yesterday just to get a soda ...          NaN     0
# 22    I visited mcdonalds on Dec 20, 2011 at 12:54 I...          NaN     1
# 23    I usually hit the drive thru once or twice a w...          NaN     0
# 24    What a joke.Don't do take out as you will not ...          NaN     0
# 25    I wish I can give zero stars. Freezing cold re...          NaN     0
# 26    I agree with most reviewers on this one. Staff...          NaN     1
# 27    I don't think this location deserves even one ...          NaN     0
# 28    This is one rude Mcdonalds! The food takes lon...          NaN     1
# 29    the managers at this mcdonalds are awesome but...          NaN     0
# ...                                                 ...          ...   ...
# 1495                 very good mcdonald's ,good service          NaN     0
# 1496  Came here for the McCafe.Coffee was a little l...          NaN     0
# 1497  I actually got in an accident trying to leave ...          NaN     0
# 1498  Came here for breakfast and there was total ch...          NaN     0
# 1499  I dont like mcdonalds but go once in a great w...          NaN     1
# 1500  If they went any slower, I would have grown a ...          NaN     0
# 1501  I am very amazed at the hard working employees...          NaN     0
# 1502  Managers are rude to customers, I asked if the...          NaN     1
# 1503  Best place on Park Avenue to meet homeless peo...          NaN     0
# 1504  Worst customer service ever!!!!!!!!!!!!over 30...          NaN     1
# 1505  I won't be critical because it was only a Mcdo...          NaN     1
# 1506  My mom needed to meet a client to pick up docu...          NaN     0
# 1507  This is not a family-friendly location. There'...          NaN     0
# 1508  I love this McDonalds! The workers are always ...          NaN     0
# 1509  Really rude workers and customer service was j...          NaN     1
# 1510  WORST MCDONALDS EVER!Every single time we have...          NaN     0
# 1511  Worst service ever!!!! There was so much trash...          NaN     1
# 1512  Normally I don't review a chain unless somethi...          NaN     1
# 1513  Every time I come here they mess up my order.....          NaN     0
# 1514  Don't go here if you're looking for fast food....          NaN     0
# 1515  Ok ok ok, I know it's only a McDonald's, BUT t...          NaN     0
# 1516  Okay so I came in here yesterday around 4:15 P...          NaN     0
# 1517  The drive thru got our order wrong AGAIN. I ca...          NaN     1
# 1518  Breakfast for the family and kids. ξ8 of us. ...          NaN     0
# 1519  If I could put zero stars, it would deserve th...          NaN     1
# 1520  I enjoyed the part where I repeatedly asked if...          NaN     0
# 1521  Worst McDonalds I've been in in a long time! D...          NaN     0
# 1522  When I am really craving for McDonald's, this ...          NaN     0
# 1523  Two points right out of the gate: 1. Thuggery ...          NaN     0
# 1524  I wanted to grab breakfast one morning before ...          NaN     0
#
# [1471 rows x 12 columns]

# %% [markdown]
# ## Task 4
#
# 1. Define X (the **review** column) and y (the **rude** column).
# 2. Split X and y into training and testing sets (using the parameter **`random_state=1`**).
# 3. Use CountVectorizer (with the **default parameters**) to create document-term matrices from X_train and X_test.

# %%
X = mcd.review
y = mcd.rude
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ## Task 5
#
# Fit a Multinomial Naive Bayes model to the training set, calculate the **predicted probabilites** (not the class predictions) for the testing set, and then calculate the **AUC**. Repeat this task using a logistic regression model to see which of the two models achieves a better AUC.
#
# - **Note:** Because McDonald's only cares about ranking the comments by the likelihood that they refer to rude service, **classification accuracy** is not the relevant evaluation metric. **Area Under the Curve (AUC)** is a more useful evaluation metric for this scenario, since it measures the ability of the classifier to assign higher predicted probabilities to positive instances than to negative instances.
# - **Hint:** [Evaluating a classification model](https://github.com/justmarkham/scikit-learn-videos/blob/master/09_classification_metrics.ipynb) explains how to calculate predicted probabilities and AUC, and my [blog post and video](http://www.dataschool.io/roc-curves-and-auc-explained/) explain AUC in-depth.

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer()
vect.fit(X_train)
X_train_dtm = vect.transform(X_train)
X_test_dtm = vect.transform(X_test)

# First, Naive Bayes

from sklearn.naive_bayes import MultinomialNB
nb = MultinomialNB()
nb.fit(X_train_dtm,y_train)
y_pred_prob_nb = nb.predict_proba(X_test_dtm)[:,1]

from sklearn import metrics
fpr_nb, tpr_nb, thresholds_nb = metrics.roc_curve(y_test, y_pred_prob_nb)
metrics.auc(fpr_nb, tpr_nb)
# Out:
# 0.84196471149260854

# %%
# Next, logistic regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train_dtm,y_train)
y_pred_prob_lr = lr.predict_proba(X_test_dtm)[:,1]

fpr_lr, tpr_lr, thresholds_lr = metrics.roc_curve(y_test, y_pred_prob_lr)
metrics.auc(fpr_lr, tpr_lr) # Naive Bayes wins!
# Out:
# 0.82339850580193941

# %% [markdown]
# ## Task 6
#
# Using either Naive Bayes or logistic regression (whichever one had a better AUC in the previous step), try **tuning CountVectorizer** using some of the techniques we learned in class. Check the testing set **AUC** after each change, and find the set of parameters that increases AUC the most.
#
# - **Hint:** It is highly recommended that you adapt the **`tokenize_test()`** function from class for this purpose, since it will allow you to iterate quickly through different sets of parameters.

# %%
def tokenize_test(vect):
    X_train_dtm = vect.fit_transform(X_train)
    X_test_dtm = vect.transform(X_test)
    print('Features: ', X_train_dtm.shape[1])
    nb = MultinomialNB()
    nb.fit(X_train_dtm, y_train)
    y_pred_prob = nb.predict_proba(X_test_dtm)[:,1]
    fpr, tpr, thresholds = metrics.roc_curve(y_test, y_pred_prob)
    print('AUC: ', metrics.auc(fpr, tpr))
    
# Check with default settings
tokenize_test(vect)
# Out:
# Features:  7300
# AUC:  0.841964711493

# %%
# Don't convert to lower-case
tokenize_test(CountVectorizer(lowercase=False))
# Out:
# Features:  8742
# AUC:  0.840375139088

# %%
# Add in 2-grams
tokenize_test(CountVectorizer(ngram_range=(1, 2)))
# Out:
# Features:  57936
# AUC:  0.818375457002

# %%
# Remove stopwords
tokenize_test(CountVectorizer(stop_words='english')) # Finally making some progress!
# Out:
# Features:  7021
# AUC:  0.853266571292

# %%
# ignore common terms
tokenize_test(CountVectorizer(max_df=0.5)) # Not as good as stopwords
# Out:
# Features:  7291
# AUC:  0.844794150374

# %%
# 1000 most frequent terms
tokenize_test(CountVectorizer(max_features=1000))
# Out:
# Features:  1000
# AUC:  0.830074709903

# %%
# Terms appearing in >1 documents
tokenize_test(CountVectorizer(min_df=2))
# Out:
# Features:  3500
# AUC:  0.844221904308

# %%
# 1- and 2-grams appearing in >1 documents
tokenize_test(CountVectorizer(ngram_range=(1, 2), min_df=2)) # still not as good as removing stopwords
# Out:
# Features:  14485
# AUC:  0.840057224607

# %%
# fancy it up
tokenize_test(CountVectorizer(ngram_range=(1, 2), min_df=4, stop_words='english')) # best so far
# Out:
# Features:  2441
# AUC:  0.856731839135

# %% [markdown]
# ## Task 7 (Challenge)
#
# The **city** column might be predictive of the response, but we are not currently using it as a feature. Let's see whether we can increase the AUC by adding it to the model:
#
# 1. Create a new DataFrame column, **review_city**, that concatenates the **review** text with the **city** text. One easy way to combine string columns in pandas is by using the [`Series.str.cat()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.cat.html) method. Make sure to use the **space character** as a separator, as well as replacing **null city values** with a reasonable string value (such as 'na').
# 2. Redefine X as the **review_city** column, and re-split X and y into training and testing sets.
# 3. When you run **`tokenize_test()`**, CountVectorizer will simply treat the city as an extra word in the review, and thus it will automatically be included in the model! Check to see whether it increased or decreased the AUC of your **best model**.

# %%
mcd.city.fillna(value='NoCity',inplace=True)
mcd['review_city'] = mcd.city.str.cat(mcd.review,sep=' ')
# TODO: Check Slack channel about this warning
X_city = mcd.review_city
X_train, X_test, y_train, y_test = train_test_split(X_city, y, random_state=1)
tokenize_test(CountVectorizer(ngram_range=(1, 2), min_df=4, stop_words='english'))
# Out:
# Features:  2487
# AUC:  0.859259259259

# %% [markdown]
# Modest improvement on my best model.

# %% [markdown]
# ## Task 8 (Challenge)
#
# The **policies_violated:confidence** column may be useful, since it essentially represents a measurement of the training data quality. Let's see whether we can improve the AUC by only training the model using the highest-quality rows!
#
# To accomplish this, your first sub-task is to **calculate the mean confidence score for each row**, and then store those mean scores in a new column. For example, the confidence scores for the first row are `1.0\r\n0.6667\r\n0.6667`, so you should calculate a mean of `0.7778`. Here are the suggested steps:
#
# 1. Using the [`Series.str.split()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.str.split.html) method, convert the **policies_violated:confidence** column into lists of one or more "confidence scores". Save the results as a new DataFrame column called **confidence_list**.
# 2. Define a function that calculates the mean of a list of numbers, and pass that function to the [`Series.apply()`](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.apply.html) method of the **confidence_list** column. That will calculate the mean confidence score for each row. Save those scores in a new DataFrame column called **confidence_mean**.
#     - **Hint:** This [code snippet](http://chrisalbon.com/python/pandas_apply_operations_to_dataframes.html) may help you to understand the `Series.apply()` method.

# %%
mcd['confidence_list'] = mcd['policies_violated:confidence'].str.split('\n')

def strmean(x):
    y = [float(z) for z in x]
    return(np.mean(y))

mcd['confidence_mean'] = mcd['confidence_list'].apply(strmean)

# %% [markdown]
# Your second sub-task is to **create a new DataFrame with only the highest-quality rows**, meaning those with a mean score of 1, and then repeat the model building and evaluation process with the new DataFrame. Here are the suggested steps:
#
# 1. Create a new DataFrame that only includes the rows with a **confidence_mean** of 1. Compare the shapes of the original and new DataFrames.
# 2. Redefine X and y using the new DataFrame, and re-split X and y into training and testing sets.
# 3. Check to see whether this process increased or decreased the AUC of your **best model**.
# 4. Try **re-tuning** CountVectorizer to maximize the AUC, to see if this strategy was worthwhile.

# %%
mcd_best = mcd[mcd.confidence_mean == 1].copy()
print(mcd.shape)
print(mcd_best.shape)
# Out:
# (1471, 15)
# (785, 15)

# %%
X = mcd_best.review
y = mcd_best.rude
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
tokenize_test(CountVectorizer(ngram_range=(1, 2), min_df=4, stop_words='english')) # previous was 0.8567
# Out:
# Features:  1239
# AUC:  0.874773374773

# %%
X = mcd_best.review_city
y = mcd_best.rude
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)
tokenize_test(CountVectorizer(ngram_range=(1, 2), min_df=4, stop_words='english')) # previous was 0.8593
# Out:
# Features:  1262
# AUC:  0.870240870241

# %% [markdown]
# I wasn't able to improve things much from here. Turns out the city information doesn't help anymore when you go with high-confidence.

# %% [markdown]
# ## Task 9 (Challenge)
#
# New comments have been submitted to the McDonald's website, and you need to **score them with the likelihood** that they are referring to rude service.
#
# 1. Before making predictions on out-of-sample data, it is important to re-train your model on all relevant data using the tuning parameters and preprocessing steps that produced the best AUC above.
#     - In other words, X should be defined using either **all rows** or **only those rows with a confidence_mean of 1**, whichever produced a better AUC above.
#     - X should refer to either the **review column** or the **review_city column**, whichever produced a better AUC above.
#     - CountVectorizer should be instantiated with the **tuning parameters** that produced the best AUC above.
#     - **`train_test_split()`** should not be used during this process.
# 2. Build a document-term matrix (from X) called **X_dtm**, and examine its shape.
# 3. Read the new comments stored in **`mcdonalds_new.csv`** into a DataFrame called **new_comments**, and examine it.
# 4. If your model uses a **review_city** column, create that column in the new_comments DataFrame. (Otherwise, skip this step.)
# 5. Build a document_term matrix (from the **new_comments** DataFrame) called **new_dtm**, and examine its shape.
# 6. Train your best model (Naive Bayes or logistic regression) using **X_dtm** and **y**.
# 7. Predict the "rude probability" for each comment in **new_dtm**, and store the probabilities in an object called **new_pred_prob**.
# 8. Print the **full text** for each new comment alongside its **"rude probability"**. (You may need to [increase the max_colwidth](http://pandas.pydata.org/pandas-docs/stable/options.html) to see the full text.) Examine the results, and comment on how well you think the model performed!

# %%
X = mcd_best.review
y = mcd_best.rude
vect = CountVectorizer(ngram_range=(1, 2), min_df=4, stop_words='english')
vect.fit(X)
X_dtm = vect.transform(X)
print(X_dtm.shape)
print(y.shape)
print(mcd_best.shape)
# Out:
# (785, 1589)
# (785,)
# (785, 15)

# %%
new_comments = pd.read_csv('mcdonalds_new.csv') 
X_new = new_comments.review
new_dtm = vect.transform(X_new)
new_dtm.shape
# Out:
# (10, 1589)

# %%
nb = MultinomialNB()
nb.fit(X_dtm, y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
new_pred_prob = nb.predict_proba(new_dtm)[:,1]
new_pred_prob
# Out:
# array([ 0.1757734 ,  0.00260284,  0.98523926,  0.00347937,  0.06487435,
#         0.00137143,  0.12673981,  0.99996522,  0.08411733,  0.00808323])

# %%
new_comments['rude_prob'] = new_pred_prob
maxlen = int(max(new_comments['review'].apply(len)))
pd.set_option('max_colwidth',maxlen)
new_comments
# Out:
# <class 'int'>
#           city  \
# 0    Las Vegas
# 1      Chicago
# 2  Los Angeles
# 3     New York
# 4     Portland
# 5      Houston
# 6      Atlanta
# 7       Dallas
# 8    Cleveland
# 9          NaN
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  review  \
# 0  Went through the drive through and ordered a #10 (cripsy sweet chili chicken wrap) without fries- the lady couldn't understand that I did not want fries and charged me for them anyways. I got the wrong order- a chicken sandwich and a large fries- my boyfriend took it back inside to get the correct order. The gentleman that ordered the chicken sandwich was standing there as well and she took the bag from my bf- glanced at the insides and handed it to the man without even offering to replace. I mean with all the scares about viruses going around... ugh DISGUSTING SERVICE. Then when she gave him the correct order my wrap not only had the sweet chili sauce on it, but the nasty (just not my first choice) ranch dressing on it!!!! I mean seriously... how lazy can you get!!!! I worked at McDonalds in Texas when I was 17 for about 8 months and I guess I was spoiled with good management. This was absolutely ridiculous. I was beyond disappoin...
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Phenomenal experience. Efficient and friendly staff. Clean restrooms, good, fast service and bilingual staff. One of the best restaurants in the chain.
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Ghetto lady helped me at the drive thru. Very rude and disrespectful to the co workers. Never coming back. Yuck!
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Close to my workplace. It was well manged before. Now it's OK. The parking can be tight sometimes. Like all McDonald's, prices are getting expensive.
# 4                                                                                                                                                                                                                                                                                                                                                                                              I've made at least 3 visits to this particular location just because it's right next to my office building.. and all my experience have been consistently bad.  There are a few helpers taking your orders throughout the drive-thru route and they are the worst. They rush you in placing an order and gets impatient once the order gets a tad bit complicated.  Don't even bother changing your mind oh NO! They will glare at you and snap at you if you want to change something.  I understand its FAST food, but I want my order placed right.  Not going back if I can help it.
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Why did I revisited this McDonald's  again.  I needed to use the restroom  facilities  and the women's bathroom didn't have soap, the floor was wet,  the bathroom stink, and the toilets were nasty. This McDonald's is very nasty.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      This specific McDonald's is the bar I hold all other fast food joints to now. Been working in this area for 3 years now and gone to this location many times for drive-through pickup. Service is always fast, food comes out right, and the staff is extremely warm and polite.
# 7                                                                                                                                                                                                                                                                                                                         My friend and I stopped in to get a late night snack and we were refused service. The store claimed to be 24 hours and the manager was standing right there doing paper work but would not help us. The cashier was only concerned with doing things for the drive thru and said that the manager said he wasn't allowed to help us. We thought it was a joke at first but when realized it wasn't we said goodbye and they just let us leave. I work in a restaurant and this is by far the worst service I have ever seen. I know it was late and maybe they didn't want to be there but it was completely ridiculous. I think the manager should be fired.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Friendly people but completely unable to deliver what was ordered at the drive through.  Out of my last 6 orders they got it right 3 times.  Incidentally, the billing was always correct - they just could not read the order and deliver.  Very frustrating!
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Having visited many McDonald's over the years, I have to say that this one is the most efficient one ever! Even though it is still fast food, the service at the drive-thru is the best. They rarely make a mistake and I never see anyone parked in the drive-thru slots where they bring food out because they don't have it ready. So, if you like McDonald's fast food, it doesn't get any better than this.
#
#    rude_prob
# 0   0.175773
# 1   0.002603
# 2   0.985239
# 3   0.003479
# 4   0.064874
# 5   0.001371
# 6   0.126740
# 7   0.999965
# 8   0.084117
# 9   0.008083

# %% [markdown]
# It seems to be doing OK -- \#4 was definitely about rude service, and yet it scored lower than \#6, which definitely wasn't. It nailed \#2 and \#7.
